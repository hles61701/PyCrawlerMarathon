# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = bs(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開

# %% [markdown]
# ## 在請求中帶入 cookie

# %%
cookies = {'over18':'1'}
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False, cookies = cookies)
soup = bs(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 想婚的日本女性對普通男性的條件?
#
#
# hmt17
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hmt17 的文章
#
#
# 12/09
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.11.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
# 11/21
# !
#
#
#
# 爆
#
# [協尋] 11/23晚間 東勢往卓蘭行車記錄器
#
#
# ding88510
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ding88510 的文章
#
#
# 11/28
# M
#
#
#
# 35
#
# [協尋] 11/30宜蘭軍民/長春路口行車記錄器
#
#
# dmeiki
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dmeiki 的文章
#
#
# 11/30
#
#
#
#
# 6
#
# [公告] 十二鬼月置底閒聊區
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
# 12/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。

# %% [markdown]
# ## 先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = bs(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] cyberpunk2077是電影還是遊戲？？
#
#
# Ericz7000
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ericz7000 的文章
#
#
# 12/10
#
#
#
#
# 11
#
# [問卦] 電鰻在人類發現電之前叫啥
#
#
# hellomotogg
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hellomotogg 的文章
#
#
# 12/10
#
#
#
#
# 1
#
# [問卦] 覺得算會計很無聊 適合當會計師嗎？
#
#
# paulabxz123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 paulabxz123 的文章
#
#
# 12/10
#
#
#
#
#
#
# [問卦] 廠商怎麼知道我的mail信箱啊？
#
#
# wakaura
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 wakaura 的文章
#
#
# 12/10
#
#
#
#
#
#
# [問卦] 學弟發出了很舒服的聲音....
#
#
# algebraic
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 algebraic 的文章
#
#
# 12/10
#
#
#
#
#
#
# [新聞]「真空」其實富含粒子 科學家提出驗證實驗
#
#
# jackliao1990
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jackliao1990 的文章
#
#
# 12/10
#
#
#
#
# 6
#
# [問卦] 帝王蟹肉棒是啥小？
#
#
# kevin19528
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kevin19528 的文章
#
#
# 12/10
#
#
#
#
# 5
#
# [問卦] 周杰倫入門要聽哪首？
#
#
# jouen
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 jouen 的文章
#
#
# 12/10
#
#
#
#
#
#
# [問卦] 沒什麼 沒什麼 不過是傷口
#
#
# HDSM
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 HDSM 的文章
#
#
# 12/10
#
#
#
#
#
#
# [問卦] 有沒有和牛定義的八卦？
#
#
# moopend0073
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 moopend0073 的文章
#
#
# 12/10
#
#
#
#
# 1
#
# [問卦] 人生題如何選? 老年得病
#
#
# TokyoHard
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 TokyoHard 的文章
#
#
# 12/10
#
#
#
#
#
#
# [新聞] 男子突揮刀自宮　醫花8小時阻練神功
#
#
# b33
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 b33 的文章
#
#
# 12/10
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.11.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
# 11/21
# !
#
#
#
# 爆
#
# [協尋] 11/23晚間 東勢往卓蘭行車記錄器
#
#
# ding88510
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ding88510 的文章
#
#
# 11/28
# M
#
#
#
# 36
#
# [協尋] 11/30宜蘭軍民/長春路口行車記錄器
#
#
# dmeiki
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dmeiki 的文章
#
#
# 11/30
#
#
#
#
# 6
#
# [公告] 十二鬼月置底閒聊區
#
#
# ubcs
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ubcs 的文章
#
#
# 12/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
# C:\Users\wei\anaconda3\envs\env_py38_1091105\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
