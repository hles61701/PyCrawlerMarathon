# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
import json

re = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data = json.loads(re.text)
data
# Out:
# [{'id': 234771488,
#   'title': '老闆才說交給他吧，結果就gg了',
#   'excerpt': '週末帶著我們家臭狗去拍網美照，後來餐點上來，老闆看我們牽著它怕我們不方便用餐，又正好也要帶狗散步，就信誓旦旦的對我們說：“這隻就交給我吧！”然後就把它牽去散步了。我們也正好有時間可以好好品嚐餐點。結果',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T04:46:46.762Z',
#   'updatedAt': '2020-11-10T04:56:57.034Z',
#   'commentCount': 31,
#   'likeCount': 1150,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '狗', '哈士奇', '洗澡'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '二師兄老北',
#   'department': 'earlthehusky',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'abd5b153-692c-4675-b398-14a6b95e8c9f',
#     'url': 'https://i.imgur.com/wO54kGJl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/wO54kGJl.jpg',
#     'thumbnail': 'https://i.imgur.com/wO54kGJl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': 'abd5b153-692c-4675-b398-14a6b95e8c9f',
#     'url': 'https://i.imgur.com/wO54kGJ.jpg',
#     'normalizedUrl': 'https://imgur.com/wO54kGJ',
#     'thumbnail': 'https://i.imgur.com/wO54kGJl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': '315bffde-2516-4151-a7e5-590153e816f7',
#     'url': 'https://i.imgur.com/D5cGTUO.jpg',
#     'normalizedUrl': 'https://imgur.com/D5cGTUO',
#     'thumbnail': 'https://i.imgur.com/D5cGTUOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': '231b4da4-90ab-47fc-8a76-e184d902cd7b',
#     'url': 'https://i.imgur.com/nhFbsi5.jpg',
#     'normalizedUrl': 'https://imgur.com/nhFbsi5',
#     'thumbnail': 'https://i.imgur.com/nhFbsi5l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': '6e8ab31e-368c-4d64-a707-d30dd582d686',
#     'url': 'https://i.imgur.com/SoXnF4V.jpg',
#     'normalizedUrl': 'https://imgur.com/SoXnF4V',
#     'thumbnail': 'https://i.imgur.com/SoXnF4Vl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': '163eea63-ce96-415d-b511-04502774a98f',
#     'url': 'https://i.imgur.com/vrcO9ah.jpg',
#     'normalizedUrl': 'https://imgur.com/vrcO9ah',
#     'thumbnail': 'https://i.imgur.com/vrcO9ahl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': '7202e386-3a64-4d86-913e-9a6ac5a547d7',
#     'url': 'https://i.imgur.com/PTcoheW.jpg',
#     'normalizedUrl': 'https://imgur.com/PTcoheW',
#     'thumbnail': 'https://i.imgur.com/PTcoheWl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'},
#    {'id': 'c512a8e2-98b3-4833-b57a-9496e1e3368f',
#     'url': 'https://i.imgur.com/KUv6Ezv.jpg',
#     'normalizedUrl': 'https://imgur.com/KUv6Ezv',
#     'thumbnail': 'https://i.imgur.com/KUv6Ezvl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:46:46.762Z',
#     'updatedAt': '2020-11-10T04:56:57.034Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1099},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 49},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/wO54kGJ.jpg'},
#    {'url': 'https://i.imgur.com/D5cGTUO.jpg'},
#    {'url': 'https://i.imgur.com/nhFbsi5.jpg'},
#    {'url': 'https://i.imgur.com/SoXnF4V.jpg'},
#    {'url': 'https://i.imgur.com/vrcO9ah.jpg'},
#    {'url': 'https://i.imgur.com/PTcoheW.jpg'},
#    {'url': 'https://i.imgur.com/KUv6Ezv.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234769783,
#   'title': '貓真的是液體做的，尤其是肚皮',
#   'excerpt': '閒來無事的時候很愛揉捏貓咪的肚皮，雖然有的貓是地雷不要輕易嘗試，但我家二橘的肚子都有神秘開關，揉個兩下就會緩慢癱軟，流到床上然後瘋狂舔手，是我的手不是他的那個被貓舔的觸感真的是hen蘇胡，另外一隻走失',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-09T17:45:38.554Z',
#   'updatedAt': '2020-11-09T17:45:38.554Z',
#   'commentCount': 29,
#   'likeCount': 402,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '橘貓', '虎斑', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'Kelly',
#   'department': 'kellyl',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'ab1bc44e-afc6-43b8-b7fa-188d957819db',
#     'url': 'https://vivid.dcard.tw/Public/f78bf02d-8d2f-494c-b477-efb7089f9139/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/f78bf02d-8d2f-494c-b477-efb7089f9139/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/f78bf02d-8d2f-494c-b477-efb7089f9139/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': 'ab1bc44e-afc6-43b8-b7fa-188d957819db',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/f78bf02d-8d2f-494c-b477-efb7089f9139?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/f78bf02d-8d2f-494c-b477-efb7089f9139/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': '648451fc-7525-4414-b900-3a390d3c76c9',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/4d77b45d-b8bf-4b9f-898a-809c9f5b4304?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/4d77b45d-b8bf-4b9f-898a-809c9f5b4304/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': '19622455-b713-4ff1-9f2f-2086e56ae966',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/04160828-7d0e-440f-9873-595f247ff2d2?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/04160828-7d0e-440f-9873-595f247ff2d2/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': 'f0ef6723-ff3b-4cb5-933b-b35fd49854af',
#     'url': 'https://i.imgur.com/Maetooy.jpg',
#     'normalizedUrl': 'https://imgur.com/Maetooy',
#     'thumbnail': 'https://i.imgur.com/Maetooyl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': 'f3ddea8b-2507-4a08-9585-b91c10db06a6',
#     'url': 'https://i.imgur.com/CENkz1j.jpg',
#     'normalizedUrl': 'https://imgur.com/CENkz1j',
#     'thumbnail': 'https://i.imgur.com/CENkz1jl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'},
#    {'id': '12b77076-7ec8-4a83-85e6-a2bf8a37ee5d',
#     'url': 'https://i.imgur.com/WYdEqqC.jpg',
#     'normalizedUrl': 'https://imgur.com/WYdEqqC',
#     'thumbnail': 'https://i.imgur.com/WYdEqqCl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:45:38.554Z',
#     'updatedAt': '2020-11-09T17:45:38.554Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 389},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 13}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/f78bf02d-8d2f-494c-b477-efb7089f9139/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/4d77b45d-b8bf-4b9f-898a-809c9f5b4304/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/04160828-7d0e-440f-9873-595f247ff2d2/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/Maetooy.jpg'},
#    {'url': 'https://i.imgur.com/CENkz1j.jpg'},
#    {'url': 'https://i.imgur.com/WYdEqqC.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234774056,
#   'title': '風暴國際模特兒虐鼠😡😡😡',
#   'excerpt': '明顯虐鼠行為，拍攝者不但不阻止，甚至發上社群媒體，還認為是很好笑的行為，外表看似光鮮亮麗，實則心腸歹毒，內附影片⬇️，誇張飼主⬇️，拍攝者⬇️，倉鼠是小小的生物，但並非你的玩具，不愛他也請不要傷害他啊',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T12:40:35.087Z',
#   'updatedAt': '2020-11-10T12:40:35.087Z',
#   'commentCount': 36,
#   'likeCount': 182,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['國際風暴', '模特兒', '虐鼠', '寵物', '黑特'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '🙂',
#   'department': 'cccc._.',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3e4a2775-c0ae-4f4a-be5b-3fc8a97e1814',
#     'url': 'https://vivid.dcard.tw/Public/ac374704-49eb-4bf4-8c56-b1030741d796/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/ac374704-49eb-4bf4-8c56-b1030741d796/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/ac374704-49eb-4bf4-8c56-b1030741d796/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T12:40:35.087Z',
#     'updatedAt': '2020-11-10T12:40:35.087Z'},
#    {'id': '3e4a2775-c0ae-4f4a-be5b-3fc8a97e1814',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/ac374704-49eb-4bf4-8c56-b1030741d796?r=1.5686274509803921',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/ac374704-49eb-4bf4-8c56-b1030741d796/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T12:40:35.087Z',
#     'updatedAt': '2020-11-10T12:40:35.087Z'},
#    {'id': 'b41893f4-1be6-44a0-806d-8812d3a8f52a',
#     'url': 'https://i.imgur.com/zF00luE.jpg',
#     'normalizedUrl': 'https://imgur.com/zF00luE',
#     'thumbnail': 'https://i.imgur.com/zF00luEl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T12:40:35.087Z',
#     'updatedAt': '2020-11-10T12:40:35.087Z'},
#    {'id': '5094d97c-a8c8-4bbb-889c-78e77b047a41',
#     'url': 'https://i.imgur.com/Z9S7JF1.jpg',
#     'normalizedUrl': 'https://imgur.com/Z9S7JF1',
#     'thumbnail': 'https://i.imgur.com/Z9S7JF1l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T12:40:35.087Z',
#     'updatedAt': '2020-11-10T12:40:35.087Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 115},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 63},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/ac374704-49eb-4bf4-8c56-b1030741d796/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/zF00luE.jpg'},
#    {'url': 'https://i.imgur.com/Z9S7JF1.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234770921,
#   'title': '牠適合當網紅嗎？',
#   'excerpt': '很多人說：吉娃娃是外星狗，但身為牠的主人，我覺得牠超級可愛，於是....，我朋友一直覺得牠很有喜感、很療癒，朋友說：他是網紅狗，所以朋友還幫牠辦了IG 🤣🤣 （uglydo），讓大家療癒一下，看看 會',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T02:54:46.943Z',
#   'updatedAt': '2020-11-11T01:09:05.112Z',
#   'commentCount': 46,
#   'likeCount': 101,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['網紅', '寵物', '狗', '可愛', '吉娃娃'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '🍦',
#   'department': 'doehi',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4c1a52c3-d15d-4240-a58d-a68077cde810',
#     'url': 'https://i.imgur.com/CD3c8cel.jpg',
#     'normalizedUrl': 'https://i.imgur.com/CD3c8cel.jpg',
#     'thumbnail': 'https://i.imgur.com/CD3c8cel.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T03:00:34.768Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': '4c1a52c3-d15d-4240-a58d-a68077cde810',
#     'url': 'https://i.imgur.com/CD3c8ce.jpg',
#     'normalizedUrl': 'https://imgur.com/CD3c8ce',
#     'thumbnail': 'https://i.imgur.com/CD3c8cel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T03:00:34.768Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': 'ac71b357-27d4-4647-b72c-bafa5846606c',
#     'url': 'https://i.imgur.com/aDdFl0q.jpg',
#     'normalizedUrl': 'https://imgur.com/aDdFl0q',
#     'thumbnail': 'https://i.imgur.com/aDdFl0ql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T02:54:46.943Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': 'dfbd851c-4882-451d-886b-566a948dcc71',
#     'url': 'https://i.imgur.com/u4UscR0.jpg',
#     'normalizedUrl': 'https://imgur.com/u4UscR0',
#     'thumbnail': 'https://i.imgur.com/u4UscR0l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T02:54:46.943Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': '6662ad52-5d0c-42d5-9770-6b1d15fe74c8',
#     'url': 'https://i.imgur.com/xcgVlR5.jpg',
#     'normalizedUrl': 'https://imgur.com/xcgVlR5',
#     'thumbnail': 'https://i.imgur.com/xcgVlR5l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T03:00:34.768Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': 'a043e25e-68b1-4bde-ae85-0cf064397816',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/68577bee-e0d5-4449-a301-557f5a5f2572?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/68577bee-e0d5-4449-a301-557f5a5f2572/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T02:54:46.943Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': '1c54a2ca-943d-4209-8320-7f6cbff75dd1',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/fe681d6d-5cac-4b26-a8bc-01bdbdf382be?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/fe681d6d-5cac-4b26-a8bc-01bdbdf382be/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T15:09:06.848Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'},
#    {'id': '915e47a0-2234-4843-a7f1-4444d72f7d03',
#     'url': 'https://i.imgur.com/JgML86p.jpg',
#     'normalizedUrl': 'https://imgur.com/JgML86p',
#     'thumbnail': 'https://i.imgur.com/JgML86pl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-11T00:53:44.520Z',
#     'updatedAt': '2020-11-11T01:09:05.112Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 95},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 5},
#    {'id': 'aa0d425f-d530-4478-9a77-fe3aedc79eea', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/CD3c8ce.jpg'},
#    {'url': 'https://i.imgur.com/aDdFl0q.jpg'},
#    {'url': 'https://i.imgur.com/u4UscR0.jpg'},
#    {'url': 'https://i.imgur.com/xcgVlR5.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/68577bee-e0d5-4449-a301-557f5a5f2572/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/fe681d6d-5cac-4b26-a8bc-01bdbdf382be/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/JgML86p.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234771340,
#   'title': '蓋一個主子的坐姿大樓',
#   'excerpt': '兩天前才從板橋動物之家抱回家的大小姐，今天在我們家已經變成放蕩不羈的風流女孩，要淑女',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T04:16:41.568Z',
#   'updatedAt': '2020-11-10T15:30:45.722Z',
#   'commentCount': 34,
#   'likeCount': 91,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '中國文化大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'fa63726a-e171-4de8-ab64-4d1af68b72ec',
#     'url': 'https://i.imgur.com/DOg9tBUl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/DOg9tBUl.jpg',
#     'thumbnail': 'https://i.imgur.com/DOg9tBUl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:16:41.568Z',
#     'updatedAt': '2020-11-10T15:30:45.722Z'},
#    {'id': 'fa63726a-e171-4de8-ab64-4d1af68b72ec',
#     'url': 'https://i.imgur.com/DOg9tBU.jpg',
#     'normalizedUrl': 'https://imgur.com/DOg9tBU',
#     'thumbnail': 'https://i.imgur.com/DOg9tBUl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:16:41.568Z',
#     'updatedAt': '2020-11-10T15:30:45.722Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 91}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/DOg9tBU.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234774263,
#   'title': '這不是我的貓啊！',
#   'excerpt': '這是我的貓，長的帥又可愛，昨天洗完澡出來看到...，乾 這是什麼，你是誰！！！！！！！，靠 你到底是誰🤣，這張更詭異，到底是什麼把你變成這樣',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T13:13:46.681Z',
#   'updatedAt': '2020-11-10T13:15:15.189Z',
#   'commentCount': 6,
#   'likeCount': 73,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '米克斯', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '安菲不吸他命只吸焦糖',
#   'department': 'chuchu1234',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3d0581ea-f4bb-4b77-b9a6-9f0ded3b80f1',
#     'url': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/160.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/160.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/160.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 120,
#     'height': 160},
#    {'id': '3d0581ea-f4bb-4b77-b9a6-9f0ded3b80f1',
#     'url': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/39a42a9d-8c22-4759-a507-9b2c6243ed11',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '18efaf30-7725-43a8-b5e4-8b00f0653329',
#     'url': 'https://megapx-assets.dcard.tw/images/14371481-cf39-43ae-8514-37a4476533f1/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/14371481-cf39-43ae-8514-37a4476533f1',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/14371481-cf39-43ae-8514-37a4476533f1/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '6ff60b0b-0cba-45b1-a0db-a235357dcff7',
#     'url': 'https://megapx-assets.dcard.tw/images/5a5b2233-38e2-46d7-a79b-520a9f192342/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/5a5b2233-38e2-46d7-a79b-520a9f192342',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/5a5b2233-38e2-46d7-a79b-520a9f192342/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'baffb3e8-6de4-4386-9aea-fd018e1d6e1a',
#     'url': 'https://megapx-assets.dcard.tw/images/22ae5ba5-ef16-4087-a610-ed62ded43d51/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/22ae5ba5-ef16-4087-a610-ed62ded43d51',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/22ae5ba5-ef16-4087-a610-ed62ded43d51/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '8038ee83-0121-467d-ab99-fcf272dae72b',
#     'url': 'https://megapx-assets.dcard.tw/images/40f2e9ca-8ef7-4a8b-ad3d-fb5289c47dc2/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/40f2e9ca-8ef7-4a8b-ad3d-fb5289c47dc2',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/40f2e9ca-8ef7-4a8b-ad3d-fb5289c47dc2/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': 'aceb7404-2577-46a9-865b-74cc1b1f93cc',
#     'url': 'https://megapx-assets.dcard.tw/images/83f62b5c-08fa-49e8-bb12-86f326b254c5/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/83f62b5c-08fa-49e8-bb12-86f326b254c5',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/83f62b5c-08fa-49e8-bb12-86f326b254c5/160.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:13:46.681Z',
#     'updatedAt': '2020-11-10T13:15:15.189Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 58},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 14},
#    {'id': '4b018f48-e184-445f-adf1-fc8e04ba09b9', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/39a42a9d-8c22-4759-a507-9b2c6243ed11/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/14371481-cf39-43ae-8514-37a4476533f1/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/5a5b2233-38e2-46d7-a79b-520a9f192342/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/22ae5ba5-ef16-4087-a610-ed62ded43d51/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/40f2e9ca-8ef7-4a8b-ad3d-fb5289c47dc2/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/83f62b5c-08fa-49e8-bb12-86f326b254c5/1280.jpeg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234769840,
#   'title': '愛乾淨的卡通大便狗',
#   'excerpt': '繼上次的大便之後，她又學會了新的技能，話說某天回家看到這景象，正想罵男友清也不清乾淨是想怎樣^_^，突然想到他根本不在家，轉頭看了一下在床上的狗，：......好哦連你也不想看到自己的尿嗎，在這之後又',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-09T17:57:51.316Z',
#   'updatedAt': '2020-11-09T17:58:13.936Z',
#   'commentCount': 5,
#   'likeCount': 70,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '狗', '米克斯'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立中正大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '240be2ed-cfd5-4354-9b48-bf6a8f270a01',
#     'url': 'https://i.imgur.com/LunalDhl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/LunalDhl.jpg',
#     'thumbnail': 'https://i.imgur.com/LunalDhl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '240be2ed-cfd5-4354-9b48-bf6a8f270a01',
#     'url': 'https://i.imgur.com/LunalDh.jpg',
#     'normalizedUrl': 'https://imgur.com/LunalDh',
#     'thumbnail': 'https://i.imgur.com/LunalDhl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '72990240-3a17-4a09-b276-9c5c3162a7fe',
#     'url': 'https://i.imgur.com/ut0dTS7.jpg',
#     'normalizedUrl': 'https://imgur.com/ut0dTS7',
#     'thumbnail': 'https://i.imgur.com/ut0dTS7l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '2f6aed83-1ccd-416a-97fa-8c96fba09887',
#     'url': 'https://i.imgur.com/eFaLNwd.jpg',
#     'normalizedUrl': 'https://imgur.com/eFaLNwd',
#     'thumbnail': 'https://i.imgur.com/eFaLNwdl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '457b9065-c515-42d8-9874-aa9705598ca2',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/acae6fe7-e7e5-4103-af57-1acce7d7a5af?r=0.5625',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/acae6fe7-e7e5-4103-af57-1acce7d7a5af/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '021fd895-d344-45f7-a154-2a257a5984c9',
#     'url': 'https://i.imgur.com/Cwwz2yL.jpg',
#     'normalizedUrl': 'https://imgur.com/Cwwz2yL',
#     'thumbnail': 'https://i.imgur.com/Cwwz2yLl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '58678298-b3c2-4641-a2cd-5b89b69913c3',
#     'url': 'https://i.imgur.com/mAiq1uh.jpg',
#     'normalizedUrl': 'https://imgur.com/mAiq1uh',
#     'thumbnail': 'https://i.imgur.com/mAiq1uhl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'},
#    {'id': '3306d451-e3f6-476a-8f8a-0c2b1853f966',
#     'url': 'https://i.imgur.com/hH14Wz4.jpg',
#     'normalizedUrl': 'https://imgur.com/hH14Wz4',
#     'thumbnail': 'https://i.imgur.com/hH14Wz4l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T17:57:51.316Z',
#     'updatedAt': '2020-11-09T17:58:13.936Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 67},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 3}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/LunalDh.jpg'},
#    {'url': 'https://i.imgur.com/ut0dTS7.jpg'},
#    {'url': 'https://i.imgur.com/eFaLNwd.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/acae6fe7-e7e5-4103-af57-1acce7d7a5af/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/Cwwz2yL.jpg'},
#    {'url': 'https://i.imgur.com/mAiq1uh.jpg'},
#    {'url': 'https://i.imgur.com/hH14Wz4.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234771517,
#   'title': '家有小海豹 #圖多',
#   'excerpt': '我以為我養的是貓，原來是海豹阿～海豹滾~，滾來~滾去，就這樣靜靜的看著你 嘿嘿，天氣變冷了臉臉越來越黑，🤣，這是我們家的公主，非常愛跟人玩 不喜歡跟貓玩，如果要用一個字形容她，大概就是懶，因為平常大部',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T04:53:14.691Z',
#   'updatedAt': '2020-11-10T06:54:38.352Z',
#   'commentCount': 2,
#   'likeCount': 60,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['圖', '寵物', '貓', '黑面'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '中華科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '09beca42-7189-479f-bf7f-de6dc1aa239b',
#     'url': 'https://i.imgur.com/1ExYyAgl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/1ExYyAgl.jpg',
#     'thumbnail': 'https://i.imgur.com/1ExYyAgl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '09beca42-7189-479f-bf7f-de6dc1aa239b',
#     'url': 'https://i.imgur.com/1ExYyAg.jpg',
#     'normalizedUrl': 'https://imgur.com/1ExYyAg',
#     'thumbnail': 'https://i.imgur.com/1ExYyAgl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '0b6a4f6b-36f3-4d72-969c-f364de5a2320',
#     'url': 'https://i.imgur.com/fFSHzj1.jpg',
#     'normalizedUrl': 'https://imgur.com/fFSHzj1',
#     'thumbnail': 'https://i.imgur.com/fFSHzj1l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': 'f618db68-f75d-4a55-907e-31dc0ed171f3',
#     'url': 'https://i.imgur.com/nZuXyAL.jpg',
#     'normalizedUrl': 'https://imgur.com/nZuXyAL',
#     'thumbnail': 'https://i.imgur.com/nZuXyALl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '4f7e9f5f-b464-42a5-9ba1-69e27d410b5c',
#     'url': 'https://i.imgur.com/40w1o4q.jpg',
#     'normalizedUrl': 'https://imgur.com/40w1o4q',
#     'thumbnail': 'https://i.imgur.com/40w1o4ql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': 'bfef7169-e460-419f-af06-a7314fd63f95',
#     'url': 'https://i.imgur.com/kvQDmyp.jpg',
#     'normalizedUrl': 'https://imgur.com/kvQDmyp',
#     'thumbnail': 'https://i.imgur.com/kvQDmypl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': 'bea1dd64-79e5-42b2-b7e3-f066a7271656',
#     'url': 'https://i.imgur.com/g1NQxge.jpg',
#     'normalizedUrl': 'https://imgur.com/g1NQxge',
#     'thumbnail': 'https://i.imgur.com/g1NQxgel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '4aa241a6-19c9-4f5f-b202-ac07240d9e45',
#     'url': 'https://i.imgur.com/fNHsUsC.jpg',
#     'normalizedUrl': 'https://imgur.com/fNHsUsC',
#     'thumbnail': 'https://i.imgur.com/fNHsUsCl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': 'b7afffdf-8f42-4ebf-b0ec-7a92bbcfbd5d',
#     'url': 'https://i.imgur.com/toM9mvM.jpg',
#     'normalizedUrl': 'https://imgur.com/toM9mvM',
#     'thumbnail': 'https://i.imgur.com/toM9mvMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '66d429d3-8bcc-40df-829b-2182d1e0c35a',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/13c7ef93-1aa0-4a27-99f2-8b8f387ce481?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/13c7ef93-1aa0-4a27-99f2-8b8f387ce481/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '83868651-f16f-4d32-bdf8-918f8cb6c77d',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/f3a0bbef-db3c-4e87-98e2-ae024eecf1e4?r=1.0',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/f3a0bbef-db3c-4e87-98e2-ae024eecf1e4/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '78b4109f-42f3-4f70-afea-0abc1e66530b',
#     'url': 'https://i.imgur.com/pgMU8Ns.jpg',
#     'normalizedUrl': 'https://imgur.com/pgMU8Ns',
#     'thumbnail': 'https://i.imgur.com/pgMU8Nsl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '944052cf-d57b-4625-b199-bf1e6472c390',
#     'url': 'https://i.imgur.com/ahnZy7f.jpg',
#     'normalizedUrl': 'https://imgur.com/ahnZy7f',
#     'thumbnail': 'https://i.imgur.com/ahnZy7fl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '891ea2e1-bad9-4048-9b30-494f96569285',
#     'url': 'https://i.imgur.com/KTve9HL.jpg',
#     'normalizedUrl': 'https://imgur.com/KTve9HL',
#     'thumbnail': 'https://i.imgur.com/KTve9HLl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': 'eeff3282-f640-4a0d-b3f5-4eb4044e8cb3',
#     'url': 'https://i.imgur.com/HZ3mWDl.jpg',
#     'normalizedUrl': 'https://imgur.com/HZ3mWDl',
#     'thumbnail': 'https://i.imgur.com/HZ3mWDll.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'},
#    {'id': '546eb4a2-1cf3-426a-9c7e-4acbaf34dcf6',
#     'url': 'https://i.imgur.com/RnHuDF9.jpg',
#     'normalizedUrl': 'https://imgur.com/RnHuDF9',
#     'thumbnail': 'https://i.imgur.com/RnHuDF9l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T04:53:14.691Z',
#     'updatedAt': '2020-11-10T06:54:38.352Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 59},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://i.imgur.com/1ExYyAg.jpg'},
#    {'url': 'https://i.imgur.com/fFSHzj1.jpg'},
#    {'url': 'https://i.imgur.com/nZuXyAL.jpg'},
#    {'url': 'https://i.imgur.com/40w1o4q.jpg'},
#    {'url': 'https://i.imgur.com/kvQDmyp.jpg'},
#    {'url': 'https://i.imgur.com/g1NQxge.jpg'},
#    {'url': 'https://i.imgur.com/fNHsUsC.jpg'},
#    {'url': 'https://i.imgur.com/toM9mvM.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/13c7ef93-1aa0-4a27-99f2-8b8f387ce481/thumbnail.jpg'},
#    {'url': 'https://vivid.dcard.tw/Public/f3a0bbef-db3c-4e87-98e2-ae024eecf1e4/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/pgMU8Ns.jpg'},
#    {'url': 'https://i.imgur.com/ahnZy7f.jpg'},
#    {'url': 'https://i.imgur.com/KTve9HL.jpg'},
#    {'url': 'https://i.imgur.com/HZ3mWDl.jpg'},
#    {'url': 'https://i.imgur.com/RnHuDF9.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234769084,
#   'title': '超配合的女兒❤️',
#   'excerpt': '（糖果），很喜歡買一堆頭套，家裡五貓只有大女兒會配合，（小護士），這個套頭剛好比較小，女兒臉太大，（過年小紅包），還是包一下！！，（豆豆龍），我還特地買了母女裝，（硬要），（一樣過年項鍊），每次大概帶',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-09T15:50:07.950Z',
#   'updatedAt': '2020-11-09T15:50:07.950Z',
#   'commentCount': 6,
#   'likeCount': 50,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['寵物', '貓', '折耳貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '174愛貓妹',
#   'department': 'love6133',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6a997be5-2973-44e8-aaa9-230c7508a59e',
#     'url': 'https://i.imgur.com/3Xykyx8l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/3Xykyx8l.jpg',
#     'thumbnail': 'https://i.imgur.com/3Xykyx8l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': '6a997be5-2973-44e8-aaa9-230c7508a59e',
#     'url': 'https://i.imgur.com/3Xykyx8.jpg',
#     'normalizedUrl': 'https://imgur.com/3Xykyx8',
#     'thumbnail': 'https://i.imgur.com/3Xykyx8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': 'ecf935a4-04b6-4aaf-a632-631000383652',
#     'url': 'https://i.imgur.com/S3Xbcie.jpg',
#     'normalizedUrl': 'https://imgur.com/S3Xbcie',
#     'thumbnail': 'https://i.imgur.com/S3Xbciel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': '37ce221d-ffd0-4970-bdea-f7fd1b887339',
#     'url': 'https://i.imgur.com/4tSsDnk.jpg',
#     'normalizedUrl': 'https://imgur.com/4tSsDnk',
#     'thumbnail': 'https://i.imgur.com/4tSsDnkl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': '41c791ee-c224-4901-9357-eca08e5525d8',
#     'url': 'https://i.imgur.com/eA4xoSw.jpg',
#     'normalizedUrl': 'https://imgur.com/eA4xoSw',
#     'thumbnail': 'https://i.imgur.com/eA4xoSwl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': 'f1687ffc-c41a-4dac-8f02-260a9f0fc4c0',
#     'url': 'https://i.imgur.com/INJ5p3E.jpg',
#     'normalizedUrl': 'https://imgur.com/INJ5p3E',
#     'thumbnail': 'https://i.imgur.com/INJ5p3El.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'},
#    {'id': '30e6a969-a224-472a-9c09-c3ed9f3e5b6a',
#     'url': 'https://i.imgur.com/4r5zkMO.jpg',
#     'normalizedUrl': 'https://imgur.com/4r5zkMO',
#     'thumbnail': 'https://i.imgur.com/4r5zkMOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-09T15:50:07.950Z',
#     'updatedAt': '2020-11-09T15:50:07.950Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 49},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/3Xykyx8.jpg'},
#    {'url': 'https://i.imgur.com/S3Xbcie.jpg'},
#    {'url': 'https://i.imgur.com/4tSsDnk.jpg'},
#    {'url': 'https://i.imgur.com/eA4xoSw.jpg'},
#    {'url': 'https://i.imgur.com/INJ5p3E.jpg'},
#    {'url': 'https://i.imgur.com/4r5zkMO.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234771783,
#   'title': '想讓全世界都上癮（內含很多貓貓',
#   'excerpt': '第一次在寵物版po文有點小緊張XD，但總之就是要來安利我在這個世界上最愛的貓貓，他叫做 Neko🥰，是個難以減肥的胖橘貓，也是個個性非常憨厚的男生，養了他三年 從來沒聽過他對誰嘶嘶叫 只會逃跑哈哈哈',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T05:49:49.915Z',
#   'updatedAt': '2020-11-10T05:49:49.915Z',
#   'commentCount': 11,
#   'likeCount': 44,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓貓', '寵物', '可愛', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'Neko的阿母',
#   'department': 'earth0318',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3d3e0335-ba6e-4a38-ae15-4e0411189a97',
#     'url': 'https://i.imgur.com/3zzM56wl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/3zzM56wl.jpg',
#     'thumbnail': 'https://i.imgur.com/3zzM56wl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '3d3e0335-ba6e-4a38-ae15-4e0411189a97',
#     'url': 'https://i.imgur.com/3zzM56w.jpg',
#     'normalizedUrl': 'https://imgur.com/3zzM56w',
#     'thumbnail': 'https://i.imgur.com/3zzM56wl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': 'b7952ecc-19d7-4d63-a927-e3b7887e57a3',
#     'url': 'https://i.imgur.com/ihVKlLQ.jpg',
#     'normalizedUrl': 'https://imgur.com/ihVKlLQ',
#     'thumbnail': 'https://i.imgur.com/ihVKlLQl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': 'b77f7f50-8d39-4381-922e-209dc3d111b8',
#     'url': 'https://i.imgur.com/d5FpnA4.jpg',
#     'normalizedUrl': 'https://imgur.com/d5FpnA4',
#     'thumbnail': 'https://i.imgur.com/d5FpnA4l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': 'cc6a0bc4-780e-4193-a243-ab3388dabfcc',
#     'url': 'https://i.imgur.com/MhZdsiM.jpg',
#     'normalizedUrl': 'https://imgur.com/MhZdsiM',
#     'thumbnail': 'https://i.imgur.com/MhZdsiMl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': 'cb55543f-9dc2-47d0-8d71-ab09abb374fd',
#     'url': 'https://i.imgur.com/0G0dizu.jpg',
#     'normalizedUrl': 'https://imgur.com/0G0dizu',
#     'thumbnail': 'https://i.imgur.com/0G0dizul.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED', 'GOOGLE_VISION_VIOLENCE_VERY_LIKELY', 'SAFE'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '2602f833-27c2-459c-9a18-c3dad0c59e2f',
#     'url': 'https://i.imgur.com/RIwSxei.jpg',
#     'normalizedUrl': 'https://imgur.com/RIwSxei',
#     'thumbnail': 'https://i.imgur.com/RIwSxeil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '0e27e5e7-57de-401f-b91e-035aaafe4f79',
#     'url': 'https://i.imgur.com/HOBIAUq.jpg',
#     'normalizedUrl': 'https://imgur.com/HOBIAUq',
#     'thumbnail': 'https://i.imgur.com/HOBIAUql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '4473553e-11d9-44d4-bdac-cd2c673a507f',
#     'url': 'https://i.imgur.com/lH8FzNo.jpg',
#     'normalizedUrl': 'https://imgur.com/lH8FzNo',
#     'thumbnail': 'https://i.imgur.com/lH8FzNol.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '8b423ecf-e079-4164-97ae-3162d43c96da',
#     'url': 'https://i.imgur.com/bjOIugN.jpg',
#     'normalizedUrl': 'https://imgur.com/bjOIugN',
#     'thumbnail': 'https://i.imgur.com/bjOIugNl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': '585f2299-a9dc-4065-b42d-db83f12c58c6',
#     'url': 'https://i.imgur.com/DqeUjYm.jpg',
#     'normalizedUrl': 'https://imgur.com/DqeUjYm',
#     'thumbnail': 'https://i.imgur.com/DqeUjYml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'},
#    {'id': 'c8a68caa-b522-451b-b57a-63e39bfeef7b',
#     'url': 'https://i.imgur.com/uISi7R8.jpg',
#     'normalizedUrl': 'https://imgur.com/uISi7R8',
#     'thumbnail': 'https://i.imgur.com/uISi7R8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:49:49.915Z',
#     'updatedAt': '2020-11-10T05:49:49.915Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 44}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/3zzM56w.jpg'},
#    {'url': 'https://i.imgur.com/ihVKlLQ.jpg'},
#    {'url': 'https://i.imgur.com/d5FpnA4.jpg'},
#    {'url': 'https://i.imgur.com/MhZdsiM.jpg'},
#    {'url': 'https://i.imgur.com/0G0dizu.jpg'},
#    {'url': 'https://i.imgur.com/RIwSxei.jpg'},
#    {'url': 'https://i.imgur.com/HOBIAUq.jpg'},
#    {'url': 'https://i.imgur.com/lH8FzNo.jpg'},
#    {'url': 'https://i.imgur.com/bjOIugN.jpg'},
#    {'url': 'https://i.imgur.com/DqeUjYm.jpg'},
#    {'url': 'https://i.imgur.com/uISi7R8.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234775024,
#   'title': '妳是最棒的陪伴犬',
#   'excerpt': '因為我的心生病了，常常沒辦法好好與人相處，處處都擔心自己是不是做的不夠好，導致我經常一個人躲著。自從養了她之後，生活好像多了一點色彩，閒暇時間都在研究她的飲食、帶她出門散步、在社群分享與她的生活點滴。',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T15:05:37.242Z',
#   'updatedAt': '2020-11-10T15:05:37.242Z',
#   'commentCount': 4,
#   'likeCount': 39,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '狗', '黃金獵犬', '狗狗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '明新科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9665d42b-70a3-40a4-afbf-64ba10201ecb',
#     'url': 'https://i.imgur.com/savMbqvl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/savMbqvl.jpg',
#     'thumbnail': 'https://i.imgur.com/savMbqvl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'},
#    {'id': '9665d42b-70a3-40a4-afbf-64ba10201ecb',
#     'url': 'https://i.imgur.com/savMbqv.jpg',
#     'normalizedUrl': 'https://imgur.com/savMbqv',
#     'thumbnail': 'https://i.imgur.com/savMbqvl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'},
#    {'id': 'ca9d7d37-26e5-4168-b783-e33cf4a163ad',
#     'url': 'https://i.imgur.com/QedzTSA.jpg',
#     'normalizedUrl': 'https://imgur.com/QedzTSA',
#     'thumbnail': 'https://i.imgur.com/QedzTSAl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'},
#    {'id': '682094a3-092e-4abd-a585-7124efe93279',
#     'url': 'https://i.imgur.com/8JpL8hi.jpg',
#     'normalizedUrl': 'https://imgur.com/8JpL8hi',
#     'thumbnail': 'https://i.imgur.com/8JpL8hil.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'},
#    {'id': '9003a2a2-2cad-4f13-bf38-8e7000f0955a',
#     'url': 'https://i.imgur.com/WNASsod.jpg',
#     'normalizedUrl': 'https://imgur.com/WNASsod',
#     'thumbnail': 'https://i.imgur.com/WNASsodl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'},
#    {'id': '5bf20c51-f58e-4254-8142-ce1060fb20c8',
#     'url': 'https://i.imgur.com/XxBcafG.jpg',
#     'normalizedUrl': 'https://imgur.com/XxBcafG',
#     'thumbnail': 'https://i.imgur.com/XxBcafGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T15:05:37.242Z',
#     'updatedAt': '2020-11-10T15:05:37.242Z'}],
# ...
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '匿名',
#   'department': 'qwer0611',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'be3fe138-8eda-4cff-b86e-e349ae9b84cc',
#     'url': 'https://i.imgur.com/J2jhILql.jpg',
#     'normalizedUrl': 'https://i.imgur.com/J2jhILql.jpg',
#     'thumbnail': 'https://i.imgur.com/J2jhILql.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T06:31:50.069Z',
#     'updatedAt': '2020-11-10T06:31:50.069Z'},
#    {'id': 'be3fe138-8eda-4cff-b86e-e349ae9b84cc',
#     'url': 'https://i.imgur.com/J2jhILq.jpg',
#     'normalizedUrl': 'https://imgur.com/J2jhILq',
#     'thumbnail': 'https://i.imgur.com/J2jhILql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T06:31:50.069Z',
#     'updatedAt': '2020-11-10T06:31:50.069Z'},
#    {'id': '8bc1c52d-3e49-427b-9473-4b6316652ad1',
#     'url': 'https://i.imgur.com/LkQyrKp.jpg',
#     'normalizedUrl': 'https://imgur.com/LkQyrKp',
#     'thumbnail': 'https://i.imgur.com/LkQyrKpl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T06:31:50.069Z',
#     'updatedAt': '2020-11-10T06:31:50.069Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/J2jhILq.jpg'},
#    {'url': 'https://i.imgur.com/LkQyrKp.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234776655,
#   'title': '各位有看過完整影片嗎？',
#   'excerpt': '就算已經喝完了，瓶口還是會有殘留吧？第一次舔可能只舔到幾滴，但每次都這樣 會累積多少？酒精對於貓咪的傷害真的可以止於只舔到一點點嗎？不去制止反而任由貓一直這樣，就算只是覺得有趣 那拍一次也就夠了吧，大',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': 234767219,
#   'createdAt': '2020-11-11T00:42:37.217Z',
#   'updatedAt': '2020-11-11T00:47:11.635Z',
#   'commentCount': 7,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': [],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '樹人醫護管理專科學校',
#   'replyTitle': '太誇張了吧⋯⋯',
#   'mediaMeta': [{'id': '3691679e-b703-4a14-8000-8da9a2de1598',
#     'url': 'https://vivid.dcard.tw/Public/215de2fc-1594-46ba-8275-794724d1b966/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/215de2fc-1594-46ba-8275-794724d1b966/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/215de2fc-1594-46ba-8275-794724d1b966/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-11T00:42:37.217Z',
#     'updatedAt': '2020-11-11T00:47:11.635Z'},
#    {'id': '3691679e-b703-4a14-8000-8da9a2de1598',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/215de2fc-1594-46ba-8275-794724d1b966?r=1.7777777777777777',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/215de2fc-1594-46ba-8275-794724d1b966/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-11T00:42:37.217Z',
#     'updatedAt': '2020-11-11T00:47:11.635Z'},
#    {'id': '78ba06c8-08db-4f8c-9376-f961a477ab77',
#     'url': 'https://i.imgur.com/TDQgG7R.jpg',
#     'normalizedUrl': 'https://imgur.com/TDQgG7R',
#     'thumbnail': 'https://i.imgur.com/TDQgG7Rl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-11T00:44:21.759Z',
#     'updatedAt': '2020-11-11T00:47:11.635Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/215de2fc-1594-46ba-8275-794724d1b966/thumbnail.jpg'},
#    {'url': 'https://i.imgur.com/TDQgG7R.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234775659,
#   'title': '養的紅文鳥偷看我',
#   'excerpt': '某天想拍我家養的紅文鳥，（盯.....），（探頭），拍完之後我覺得牠超可愛的，也附上另一隻（牠老公）的鳥照，我覺得我好像把牠們養有一點太肥了，（飼料吃太好......',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T16:37:02.083Z',
#   'updatedAt': '2020-11-10T16:37:02.083Z',
#   'commentCount': 0,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['文鳥', '寵物', '可愛'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '國立臺中科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '778d1bc3-9292-4d2a-a84f-a6a60e40b6b0',
#     'url': 'https://i.imgur.com/IV0mCLql.jpg',
#     'normalizedUrl': 'https://i.imgur.com/IV0mCLql.jpg',
#     'thumbnail': 'https://i.imgur.com/IV0mCLql.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T16:37:02.083Z',
#     'updatedAt': '2020-11-10T16:37:02.083Z'},
#    {'id': 'b549b928-529d-4516-b7e0-db21016df8a0',
#     'url': 'https://i.imgur.com/pfcUQfe.jpg',
#     'normalizedUrl': 'https://imgur.com/pfcUQfe',
#     'thumbnail': 'https://i.imgur.com/pfcUQfel.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED', 'GOOGLE_VISION_ADULT_LIKELY', 'POSSIBLY_UNSAFE'],
#     'createdAt': '2020-11-10T16:37:02.083Z',
#     'updatedAt': '2020-11-10T16:37:02.083Z'},
#    {'id': '778d1bc3-9292-4d2a-a84f-a6a60e40b6b0',
#     'url': 'https://i.imgur.com/IV0mCLq.jpg',
#     'normalizedUrl': 'https://imgur.com/IV0mCLq',
#     'thumbnail': 'https://i.imgur.com/IV0mCLql.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T16:37:02.083Z',
#     'updatedAt': '2020-11-10T16:37:02.083Z'},
#    {'id': '503cee0b-6c69-4381-be80-1d87c4556d05',
#     'url': 'https://i.imgur.com/CL2OSd8.jpg',
#     'normalizedUrl': 'https://imgur.com/CL2OSd8',
#     'thumbnail': 'https://i.imgur.com/CL2OSd8l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T16:37:02.083Z',
#     'updatedAt': '2020-11-10T16:37:02.083Z'},
#    {'id': 'de0548df-bb5e-4aa9-a151-8e5d91e6a60f',
#     'url': 'https://i.imgur.com/mKWhcD2.jpg',
#     'normalizedUrl': 'https://imgur.com/mKWhcD2',
#     'thumbnail': 'https://i.imgur.com/mKWhcD2l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T16:37:02.083Z',
#     'updatedAt': '2020-11-10T16:37:02.083Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/pfcUQfe.jpg'},
#    {'url': 'https://i.imgur.com/IV0mCLq.jpg'},
#    {'url': 'https://i.imgur.com/CL2OSd8.jpg'},
#    {'url': 'https://i.imgur.com/mKWhcD2.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234774560,
#   'title': '問 貓咪下唇黑黑的是什麼 有圖',
#   'excerpt': '故事是這樣的，大約一個月前，領養了第3隻喵回家，陸續有帶去醫院做檢查、打預防針，醫生初步檢查過耳朵 嘴巴 皮膚等，都說沒什麼問題，不過今天我發現他嘴巴下唇有黑黑的東西，我不太確定是本來就有的斑，還是後',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T13:58:56.459Z',
#   'updatedAt': '2020-11-10T13:58:56.459Z',
#   'commentCount': 10,
#   'likeCount': 4,
#   'withNickname': True,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['寵物', '貓', '圖', '問題'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '泰夫人',
#   'department': 'ms_eh',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'a70948f1-75fd-42ab-86ee-02876bc70776',
#     'url': 'https://i.imgur.com/icnCw0S.jpg',
#     'normalizedUrl': 'https://imgur.com/icnCw0S',
#     'thumbnail': 'https://i.imgur.com/icnCw0Sl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:58:56.459Z',
#     'updatedAt': '2020-11-10T13:58:56.459Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234773937,
#   'title': '冷冷的冬天，妳的臉去哪了？！',
#   'excerpt': '天氣越來越冷了！，一早起來就要準備出門，真不想離開自己的被窩，可是...，怎麼一轉身妳就跟被被黏一起了！，真是太過分了！',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T12:19:07.587Z',
#   'updatedAt': '2020-11-10T12:19:07.587Z',
#   'commentCount': 3,
#   'likeCount': 4,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['曬貓', '貓咪真的很可愛', '貓', '米克斯', '白襪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '快抓狂的人',
#   'department': 'gh_ihu',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '13d7ff25-5e10-4f12-bd47-65dd52270680',
#     'url': 'https://vivid.dcard.tw/Public/6ef597ac-f8e1-4aa0-bc64-84f592067b80/thumbnail.jpg',
#     'normalizedUrl': 'https://vivid.dcard.tw/Public/6ef597ac-f8e1-4aa0-bc64-84f592067b80/thumbnail.jpg',
#     'thumbnail': 'https://vivid.dcard.tw/Public/6ef597ac-f8e1-4aa0-bc64-84f592067b80/thumbnail.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T12:19:07.587Z',
#     'updatedAt': '2020-11-10T12:19:07.587Z'},
#    {'id': '13d7ff25-5e10-4f12-bd47-65dd52270680',
#     'url': 'https://www.dcard.tw/v2/vivid/videos/6ef597ac-f8e1-4aa0-bc64-84f592067b80?r=1',
#     'normalizedUrl': '',
#     'thumbnail': 'https://vivid.dcard.tw/Public/6ef597ac-f8e1-4aa0-bc64-84f592067b80/thumbnail.jpg',
#     'type': 'video/vivid',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-11-10T12:19:07.587Z',
#     'updatedAt': '2020-11-10T12:19:07.587Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': True,
#   'media': [{'url': 'https://vivid.dcard.tw/Public/6ef597ac-f8e1-4aa0-bc64-84f592067b80/thumbnail.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234774180,
#   'title': '宜蘭礁溪小貓沒麻麻需要人幫忙',
#   'excerpt': '宜蘭礁溪五峰路9號對面有發現約1個月大小貓，母貓兩天沒看到了，有人可以來幫忙誘捕安置嗎~我一個人不行……宜蘭最近又濕又冷，我怕牠很快就不行了，拜託各位讓我被看到，畢竟是一條生命……',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T13:00:42.353Z',
#   'updatedAt': '2020-11-10T13:07:51.780Z',
#   'commentCount': 0,
#   'likeCount': 2,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['小貓', '礁溪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '蛋花湯',
#   'department': 'les_wang',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '3f33b865-4f6d-480c-8cd9-04a11d54db1f',
#     'url': 'https://i.imgur.com/ohybB7Tl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/ohybB7Tl.jpg',
#     'thumbnail': 'https://i.imgur.com/ohybB7Tl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:07:51.780Z',
#     'updatedAt': '2020-11-10T13:07:51.780Z'},
#    {'id': '3f33b865-4f6d-480c-8cd9-04a11d54db1f',
#     'url': 'https://i.imgur.com/ohybB7T.jpg',
#     'normalizedUrl': 'https://imgur.com/ohybB7T',
#     'thumbnail': 'https://i.imgur.com/ohybB7Tl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T13:07:51.780Z',
#     'updatedAt': '2020-11-10T13:07:51.780Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/ohybB7T.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234773146,
#   'title': '有沒有貓咪吃愛貓餡也會吐的',
#   'excerpt': '之前寵物店給了一兩包愛貓餡的試吃包，回家後給我們家喵吃 喵感覺很喜歡 會一直討，吃完後有自己去寵物店買兩包回來孝敬喵，在這之前我們家喵都沒有嘔吐的症狀，有一次 喵開始有嘔吐的症狀 （原本以為是吃太多）',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T09:55:29.461Z',
#   'updatedAt': '2020-11-10T09:55:29.461Z',
#   'commentCount': 6,
#   'likeCount': 2,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['貓', '寵物', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': '多莉多隻有幾隻',
#   'department': 'xitc8140',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '74520f05-b35d-4b9e-b359-3a7c1a51fe54',
#     'url': 'https://i.imgur.com/y27Nnt4l.jpg',
#     'normalizedUrl': 'https://i.imgur.com/y27Nnt4l.jpg',
#     'thumbnail': 'https://i.imgur.com/y27Nnt4l.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T09:55:29.461Z',
#     'updatedAt': '2020-11-10T09:55:29.461Z'},
#    {'id': '74520f05-b35d-4b9e-b359-3a7c1a51fe54',
#     'url': 'https://i.imgur.com/y27Nnt4.jpg',
#     'normalizedUrl': 'https://imgur.com/y27Nnt4',
#     'thumbnail': 'https://i.imgur.com/y27Nnt4l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T09:55:29.461Z',
#     'updatedAt': '2020-11-10T09:55:29.461Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/y27Nnt4.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False},
#  {'id': 234771701,
#   'title': '狗狗的品種',
#   'excerpt': '請問有人知道這隻狗狗的品種是什麼嗎？',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-11-10T05:32:05.325Z',
#   'updatedAt': '2020-11-10T05:32:05.325Z',
#   'commentCount': 2,
#   'likeCount': 2,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['狗狗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'nsfw': False,
#   'gender': 'F',
#   'school': 'PurpleN',
#   'department': 'violetttt_h',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '611787b1-69fd-4e3b-a8a4-bd499364c570',
#     'url': 'https://i.imgur.com/gWjqVgfl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/gWjqVgfl.jpg',
#     'thumbnail': 'https://i.imgur.com/gWjqVgfl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:32:05.325Z',
#     'updatedAt': '2020-11-10T05:32:05.325Z'},
#    {'id': '611787b1-69fd-4e3b-a8a4-bd499364c570',
#     'url': 'https://i.imgur.com/gWjqVgf.jpg',
#     'normalizedUrl': 'https://imgur.com/gWjqVgf',
#     'thumbnail': 'https://i.imgur.com/gWjqVgfl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-11-10T05:32:05.325Z',
#     'updatedAt': '2020-11-10T05:32:05.325Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'isModerator': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/gWjqVgf.jpg'}],
#   'reportReasonText': '',
#   'excerptComments': [],
#   'postAvatar': '',
#   'verifiedBadge': False}]

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'isModerator', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'excerptComments', 'postAvatar', 'verifiedBadge'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for i in data:
    print('標題:',i['title'])
    print('貼文時間:',i['createdAt'])
    print('留言人數:',i['commentCount'])
    print('按讚人數:',i['likeCount'])
    print('-------------------------------')
# Out:
# 標題: 老闆才說交給他吧，結果就gg了
# 貼文時間: 2020-11-10T04:46:46.762Z
# 留言人數: 31
# 按讚人數: 1150
# -------------------------------
# 標題: 貓真的是液體做的，尤其是肚皮
# 貼文時間: 2020-11-09T17:45:38.554Z
# 留言人數: 29
# 按讚人數: 402
# -------------------------------
# 標題: 風暴國際模特兒虐鼠😡😡😡
# 貼文時間: 2020-11-10T12:40:35.087Z
# 留言人數: 36
# 按讚人數: 182
# -------------------------------
# 標題: 牠適合當網紅嗎？
# 貼文時間: 2020-11-10T02:54:46.943Z
# 留言人數: 46
# 按讚人數: 101
# -------------------------------
# 標題: 蓋一個主子的坐姿大樓
# 貼文時間: 2020-11-10T04:16:41.568Z
# 留言人數: 34
# 按讚人數: 91
# -------------------------------
# 標題: 這不是我的貓啊！
# 貼文時間: 2020-11-10T13:13:46.681Z
# 留言人數: 6
# 按讚人數: 73
# -------------------------------
# 標題: 愛乾淨的卡通大便狗
# 貼文時間: 2020-11-09T17:57:51.316Z
# 留言人數: 5
# 按讚人數: 70
# -------------------------------
# 標題: 家有小海豹 #圖多
# 貼文時間: 2020-11-10T04:53:14.691Z
# 留言人數: 2
# 按讚人數: 60
# -------------------------------
# 標題: 超配合的女兒❤️
# 貼文時間: 2020-11-09T15:50:07.950Z
# 留言人數: 6
# 按讚人數: 50
# -------------------------------
# 標題: 想讓全世界都上癮（內含很多貓貓
# 貼文時間: 2020-11-10T05:49:49.915Z
# 留言人數: 11
# 按讚人數: 44
# -------------------------------
# 標題: 妳是最棒的陪伴犬
# 貼文時間: 2020-11-10T15:05:37.242Z
# 留言人數: 4
# 按讚人數: 39
# -------------------------------
# 標題: 做夢都會笑的招財貓
# 貼文時間: 2020-11-10T02:03:11.696Z
# 留言人數: 2
# 按讚人數: 31
# -------------------------------
# 標題: 媽的，你要多跩
# 貼文時間: 2020-11-10T13:19:48.469Z
# 留言人數: 4
# 按讚人數: 30
# -------------------------------
# 標題: 寵物溝通菜雞跪求練習個案
# 貼文時間: 2020-11-10T03:23:46.875Z
# 留言人數: 70
# 按讚人數: 24
# -------------------------------
# 標題: 幫集氣給祝福
# 貼文時間: 2020-11-10T02:05:28.022Z
# 留言人數: 5
# 按讚人數: 16
# -------------------------------
# 標題: 虐鼠😡😡😡
# 貼文時間: 2020-11-10T16:40:30.878Z
# 留言人數: 4
# 按讚人數: 12
# -------------------------------
# 標題: 傲嬌的糕哥🐶的紀錄照
# 貼文時間: 2020-11-10T06:05:48.954Z
# 留言人數: 1
# 按讚人數: 12
# -------------------------------
# 標題: 協尋！汐科 貓咪走失
# 貼文時間: 2020-11-10T16:22:27.959Z
# 留言人數: 0
# 按讚人數: 11
# -------------------------------
# 標題: #分享#解決嘔吐貓
# 貼文時間: 2020-11-09T16:23:09.875Z
# 留言人數: 9
# 按讚人數: 11
# -------------------------------
# 標題: ＃長文慎入：一年了，領養牠的歷程，及周邊分享
# 貼文時間: 2020-11-10T07:22:55.578Z
# 留言人數: 2
# 按讚人數: 10
# -------------------------------
# 標題: 半年後的柯基寶寶
# 貼文時間: 2020-11-10T07:03:54.311Z
# 留言人數: 1
# 按讚人數: 9
# -------------------------------
# 標題: 就是來曬貓圖的～
# 貼文時間: 2020-11-10T10:51:56.113Z
# 留言人數: 0
# 按讚人數: 8
# -------------------------------
# 標題: 你真的有在睡嗎..
# 貼文時間: 2020-11-10T06:31:50.069Z
# 留言人數: 4
# 按讚人數: 6
# -------------------------------
# 標題: 各位有看過完整影片嗎？
# 貼文時間: 2020-11-11T00:42:37.217Z
# 留言人數: 7
# 按讚人數: 5
# -------------------------------
# 標題: 養的紅文鳥偷看我
# 貼文時間: 2020-11-10T16:37:02.083Z
# 留言人數: 0
# 按讚人數: 5
# -------------------------------
# 標題: 問 貓咪下唇黑黑的是什麼 有圖
# 貼文時間: 2020-11-10T13:58:56.459Z
# 留言人數: 10
# 按讚人數: 4
# -------------------------------
# 標題: 冷冷的冬天，妳的臉去哪了？！
# 貼文時間: 2020-11-10T12:19:07.587Z
# 留言人數: 3
# 按讚人數: 4
# -------------------------------
# 標題: 宜蘭礁溪小貓沒麻麻需要人幫忙
# 貼文時間: 2020-11-10T13:00:42.353Z
# 留言人數: 0
# 按讚人數: 2
# -------------------------------
# 標題: 有沒有貓咪吃愛貓餡也會吐的
# 貼文時間: 2020-11-10T09:55:29.461Z
# 留言人數: 6
# 按讚人數: 2
# -------------------------------
# 標題: 狗狗的品種
# 貼文時間: 2020-11-10T05:32:05.325Z
# 留言人數: 2
# 按讚人數: 2
# -------------------------------

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

import requests
import json

# 熱門
re1 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data1 = json.loads(re.text)
comment_sum1 = 0
like_sum1 = 0
for i in data1:
    comment_sum1 += i['commentCount']
    like_sum1 += i['likeCount']
print('平均留言人數',comment_sum1/len(data1))
print('平均按讚人數',like_sum1/len(data1))
# Out:
# 平均留言人數 11.333333333333334
# 平均按讚人數 82.2

# %%
import requests
import json

# 非熱門
re2 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
data2 = json.loads(re.text)
comment_sum2 = 0
like_sum2 = 0
for i in data2:
    comment_sum2 += i['commentCount']
    like_sum2 += i['likeCount']
print('平均留言人數',comment_sum2/len(data1))
print('平均按讚人數',like_sum2/len(data1))
# Out:
# 平均留言人數 11.333333333333334
# 平均按讚人數 82.2
